# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
def f(x):
    return x**2 + 2*x + 1

points = [0, 1, 3]

for x in points:
    derivative = (f(x + 0.0001) - f(x)) / 0.0001
    print(f"x = {x}, Numerical Derivative = {derivative:.2f}")
# Out:
# x = 0, Numerical Derivative = 2.00
# x = 1, Numerical Derivative = 4.00
# x = 3, Numerical Derivative = 8.00

# %%
x = np.linspace(-4, 4, 400)
y = f(x)

plt.figure(figsize=(8,5))
plt.plot(x, y, label="f(x)=x²+2x+1")

for p in [0, 1, 3]:
    slope = 2*p + 2
    y_point = f(p)

    tangent = slope * (x - p) + y_point

    plt.plot(x, tangent, "--")
    plt.scatter(p, y_point)

plt.title("Function and Tangent Lines")
plt.grid(True)
plt.show()

# %% [markdown]
# # Task 1 Observations
#
# 1. The slope increases as x increases.
# 2. Positive slope means the function is increasing.
# 3. Near-zero slope indicates the optimization process is close to a minimum.

# %%
import pandas as pd

def loss(theta):
    return (theta - 3.5)**2 + 1

def gradient(theta):
    return 2 * (theta - 3.5)

theta = 10
learning_rate = 0.1

history = []

for i in range(15):
    grad = gradient(theta)
    current_loss = loss(theta)

    history.append([
        i,
        theta,
        current_loss,
        grad
    ])

    theta = theta - learning_rate * grad

df = pd.DataFrame(
    history,
    columns=[
        "Iteration",
        "Theta",
        "Loss",
        "Gradient"
    ]
)

df
# Out:
#     Iteration      Theta       Loss   Gradient
# 0           0  10.000000  43.250000  13.000000
# 1           1   8.700000  28.040000  10.400000
# 2           2   7.660000  18.305600   8.320000
# 3           3   6.828000  12.075584   6.656000
# 4           4   6.162400   8.088374   5.324800
# 5           5   5.629920   5.536559   4.259840
# 6           6   5.203936   3.903398   3.407872
# 7           7   4.863149   2.858175   2.726298
# 8           8   4.590519   2.189232   2.181038
# 9           9   4.372415   1.761108   1.744830
# 10         10   4.197932   1.487109   1.395864
# 11         11   4.058346   1.311750   1.116691
# 12         12   3.946677   1.199520   0.893353
# 13         13   3.857341   1.127693   0.714683
# 14         14   3.785873   1.081723   0.571746

# %%
plt.figure(figsize=(8,5))

plt.plot(
    df["Iteration"],
    df["Loss"],
    marker="o"
)

plt.title("Gradient Descent Loss Curve")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.grid(True)

plt.show()

# %%
theta = 10
learning_rate = 0.01

losses_low = []

for i in range(15):
    losses_low.append(loss(theta))
    theta = theta - learning_rate * gradient(theta)

# %%
theta = 10
learning_rate = 0.5

losses_high = []

for i in range(15):
    losses_high.append(loss(theta))
    theta = theta - learning_rate * gradient(theta)

# %%
plt.figure(figsize=(8,5))

plt.plot(losses_low, marker="o", label="LR = 0.01")
plt.plot(losses_high, marker="s", label="LR = 0.5")

plt.title("Learning Rate Comparison")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # Learning Rate Comparison
#
# 1. A low learning rate converges slowly.
# 2. A higher learning rate reaches the minimum faster.
# 3. Very large learning rates may overshoot the minimum and become unstable.

# %%
uniform_data = np.random.uniform(
    low=0,
    high=100,
    size=1000
)

normal_data = np.random.normal(
    loc=50,
    scale=15,
    size=1000
)

print("Data Generated Successfully")
# Out:
# Data Generated Successfully

# %%
print("Uniform Distribution")
print("Mean:", np.mean(uniform_data))
print("Standard Deviation:", np.std(uniform_data))

print("\nNormal Distribution")
print("Mean:", np.mean(normal_data))
print("Standard Deviation:", np.std(normal_data))
# Out:
# Uniform Distribution
# Mean: 48.09834412979662
# Standard Deviation: 29.414663199761026
#
# Normal Distribution
# Mean: 49.81684386349898
# Standard Deviation: 15.498095614623058

# %%
plt.figure(figsize=(8,5))

plt.hist(
    uniform_data,
    bins=20
)

plt.title("Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    normal_data,
    bins=20
)

plt.title("Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # Interpretation
#
# 1. Uniform distribution spreads values evenly across the range.
#
# 2. Normal distribution concentrates values around the mean and forms a bell-shaped curve.
#
# 3. The mean represents the average value, while standard deviation measures variability.
#
# 4. The normal distribution is commonly observed in real-world datasets.
#
# 5. Understanding distributions helps in machine learning and statistical analysis.

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

housing = fetch_california_housing()

df = pd.DataFrame(
    housing.data,
    columns=housing.feature_names
)

df["MedHouseVal"] = housing.target

df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.hist(figsize=(12,10))
plt.show()

# %%
df.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")
plt.show()

# %%
sample_df = df.sample(500)

sns.pairplot(
    sample_df[
        [
            "MedInc",
            "HouseAge",
            "AveRooms",
            "MedHouseVal"
        ]
    ]
)

plt.show()

# %% [markdown]
# # Key Findings
#
# 1. Median Income (MedInc) shows the strongest positive relationship with house prices.
#
# 2. The dataset contains no missing values and is suitable for analysis.
#
# 3. Most features have skewed distributions rather than perfectly normal distributions.
#
# 4. House values tend to increase in areas with higher median income.
#
# 5. Population-related features have weaker correlations with house prices.

# %% [markdown]
# # Conclusion
#
# The California Housing dataset was analyzed using descriptive statistics, visualizations, and correlation analysis. Median Income was identified as the most influential feature affecting house prices. The dataset is clean and provides valuable insights into housing trends. Exploratory Data Analysis helps understand the dataset before applying machine learning models.
